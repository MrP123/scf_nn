# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

import torch
import keras
from sklearn.datasets import load_iris

import numpy as np
import matplotlib.pyplot as plt

current_device = torch.cuda.current_device()
print(torch.cuda.get_device_name(current_device))
# Out:
# NVIDIA GeForce GTX 960

# %%
iris = load_iris()
data = iris["data"]
target = iris["target"]
target_names = iris["target_names"]

X = data[:, (0, 1, 2)] #sepal length, sepal width, petal length
Y = data[:, 3] # petal width
Z = target # species

# %%
inputs = keras.Input(shape=(3,), name='input')
x = keras.layers.Dense(16, activation='relu', name='16')(inputs)
x = keras.layers.Dense(32, activation='relu', name='32')(x)
output1 = keras.layers.Dense(1, name='cont_out')(x)
output2 = keras.layers.Dense(3, activation='softmax', name='cat_out')(x)

model = keras.Model(inputs=inputs, outputs=[output1, output2])

model.compile(loss={'cont_out': 'mean_absolute_error', 
                    'cat_out': 'sparse_categorical_crossentropy'},
              optimizer='adam',
              metrics={'cat_out': keras.metrics.SparseCategoricalAccuracy(name='acc')})

model.summary()
keras.utils.plot_model(model, "models/model_test.png", show_shapes=True, show_layer_activations=True)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 3)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 16 (Dense)          │ (None, 16)        │         64 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ 32 (Dense)          │ (None, 32)        │        544 │ 16[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cont_out (Dense)    │ (None, 1)         │         33 │ 32[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cat_out (Dense)     │ (None, 3)         │         99 │ 32[0][0]          │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 740 (2.89 KB)
#  Trainable params: 740 (2.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, {'cont_out': Y, 'cat_out': Z}, epochs=15, validation_split=0.1, batch_size=8)
# Out:
# Epoch 1/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - cat_out_acc: 0.6362 - cat_out_loss: 1.0025 - cont_out_loss: 1.7376 - loss: 2.7402 - val_cat_out_acc: 0.0000e+00 - val_cat_out_loss: 1.4210 - val_cont_out_loss: 1.2436 - val_loss: 2.6646
# Epoch 2/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - cat_out_acc: 0.5694 - cat_out_loss: 0.9476 - cont_out_loss: 0.3918 - loss: 1.3394 - val_cat_out_acc: 0.7333 - val_cat_out_loss: 0.8806 - val_cont_out_loss: 0.2910 - val_loss: 1.1716
# Epoch 3/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cat_out_acc: 0.6901 - cat_out_loss: 0.8638 - cont_out_loss: 0.3150 - loss: 1.1788 - val_cat_out_acc: 1.0000 - val_cat_out_loss: 0.7881 - val_cont_out_loss: 0.7014 - val_loss: 1.4895
# Epoch 4/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - cat_out_acc: 0.7300 - cat_out_loss: 0.8110 - cont_out_loss: 0.2570 - loss: 1.0679 - val_cat_out_acc: 0.0000e+00 - val_cat_out_loss: 0.9915 - val_cont_out_loss: 0.6382 - val_loss: 1.6297
# Epoch 5/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - cat_out_acc: 0.7179 - cat_out_loss: 0.7629 - cont_out_loss: 0.2063 - loss: 0.9692 - val_cat_out_acc: 0.0000e+00 - val_cat_out_loss: 0.8802 - val_cont_out_loss: 0.5737 - val_loss: 1.4538
# Epoch 6/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cat_out_acc: 0.7674 - cat_out_loss: 0.7144 - cont_out_loss: 0.1892 - loss: 0.9036 - val_cat_out_acc: 0.6000 - val_cat_out_loss: 0.8005 - val_cont_out_loss: 0.5007 - val_loss: 1.3011
# Epoch 7/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.7399 - cat_out_loss: 0.6799 - cont_out_loss: 0.1776 - loss: 0.8575 - val_cat_out_acc: 0.5333 - val_cat_out_loss: 0.8003 - val_cont_out_loss: 0.4944 - val_loss: 1.2946
# Epoch 8/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cat_out_acc: 0.8642 - cat_out_loss: 0.6507 - cont_out_loss: 0.1902 - loss: 0.8409 - val_cat_out_acc: 0.0667 - val_cat_out_loss: 0.8138 - val_cont_out_loss: 0.4907 - val_loss: 1.3045
# Epoch 9/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.7910 - cat_out_loss: 0.6182 - cont_out_loss: 0.1623 - loss: 0.7805 - val_cat_out_acc: 0.0000e+00 - val_cat_out_loss: 0.8611 - val_cont_out_loss: 0.3550 - val_loss: 1.2161
# Epoch 10/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cat_out_acc: 0.7775 - cat_out_loss: 0.5674 - cont_out_loss: 0.1789 - loss: 0.7463 - val_cat_out_acc: 1.0000 - val_cat_out_loss: 0.6736 - val_cont_out_loss: 0.5341 - val_loss: 1.2077
# Epoch 11/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.9065 - cat_out_loss: 0.5108 - cont_out_loss: 0.1422 - loss: 0.6531 - val_cat_out_acc: 0.0000e+00 - val_cat_out_loss: 0.8267 - val_cont_out_loss: 0.4730 - val_loss: 1.2997
# Epoch 12/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.7839 - cat_out_loss: 0.5116 - cont_out_loss: 0.1487 - loss: 0.6603 - val_cat_out_acc: 0.7333 - val_cat_out_loss: 0.6955 - val_cont_out_loss: 0.3613 - val_loss: 1.0567
# Epoch 13/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cat_out_acc: 0.9161 - cat_out_loss: 0.5225 - cont_out_loss: 0.1665 - loss: 0.6890 - val_cat_out_acc: 0.4667 - val_cat_out_loss: 0.7516 - val_cont_out_loss: 0.3250 - val_loss: 1.0766
# Epoch 14/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.8747 - cat_out_loss: 0.4845 - cont_out_loss: 0.1363 - loss: 0.6208 - val_cat_out_acc: 0.5333 - val_cat_out_loss: 0.7415 - val_cont_out_loss: 0.3387 - val_loss: 1.0802
# Epoch 15/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - cat_out_acc: 0.8964 - cat_out_loss: 0.4671 - cont_out_loss: 0.1313 - loss: 0.5984 - val_cat_out_acc: 0.9333 - val_cat_out_loss: 0.6453 - val_cont_out_loss: 0.3377 - val_loss: 0.9830

# %%
print(history.history.keys())
# Out:
# dict_keys(['cat_out_acc', 'cat_out_loss', 'cont_out_loss', 'loss', 'val_cat_out_acc', 'val_cat_out_loss', 'val_cont_out_loss', 'val_loss'])

# %%
plt.plot(history.history['cat_out_acc'])
plt.plot(history.history['val_cat_out_acc'])
plt.title('cat model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
plt.plot(history.history['cont_out_loss'])
plt.plot(history.history['val_cont_out_loss'])
plt.title('cont model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
preds = model.predict(np.array([[7.2, 3.1, 5.8], [4.9, 2.7, 1.3]])) #data of a fairly typical I. virginica & I. setosa
print(preds)

pedal_width = preds[0] #should be approximtaley 2 & 0.3
class_type = np.argmax(preds[1], axis=1) #should be class 2 & 0
class_names = [target_names[ct] for ct in class_type]

print(f"pedal_width = {pedal_width} / class_type = {class_type} --> class_name {class_names}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [array([[1.9529072 ],
#        [0.20404162]], dtype=float32), array([[0.00786996, 0.45674977, 0.5353802 ],
#        [0.7063498 , 0.22283661, 0.07081361]], dtype=float32)]
# pedal_width = [[1.9529072 ]
#  [0.20404162]] / class_type = [2 0] --> class_name [np.str_('virginica'), np.str_('setosa')]
